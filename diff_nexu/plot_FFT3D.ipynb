# %%
# %matplotlib widget
from IPython.core.display import HTML

# %%
from sampled_demand_analyzer import sampled_demand_analyzer
from paths import REPO_ROOT
import matplotlib.pyplot as plt

# %%
pickle_file = f"{REPO_ROOT}/diff_nexu/data/FFT3D nx=256 ny=256 nz=256 npRow=12_(36,5)RRG_ECMP_ASP_sent.pickle"
analyzer = sampled_demand_analyzer(pickle_file)

# %%
analyzer.raw_data["ave_latency[us]"]
# Out:
# np.float64(7.304936505984588)

# %%
analyzer.plot_violin_compare_all(scattering=True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# ani=analyzer.illustrate_matrices(num_samples=16)
# plt.close()
# HTML(ani.to_jshtml())

# %%
# ani=analyzer.illustrate_matrices(num_samples=1024)
# plt.close()
# HTML(ani.to_jshtml())

# %%
# for num_samples in [4, 8, 16, 32, 64, 128, 1024]:
#     analyzer.plot_demand_and_diff(num_samples=num_samples)

# %%
analyzer.plot_diff_demand_compare_all()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
