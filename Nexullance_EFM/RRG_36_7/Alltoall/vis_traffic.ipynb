# %%
import os
import sys
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../..')))
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '../../..')))
from IPython.core.display import display, HTML
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from traffic_visualizer import traffic_visualizer
# from helpers import *
# %matplotlib widget
# Out:
# /tmp/ipykernel_2128433/926838639.py:6: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %%
(V, D) = (36, 7)
TOPO="RRG"
ROUTING="ASP"
EPR=1
CPE=1
BENCH="Alltoall bytes=10000"
SUFFIX="ROUTERLINKS16GBps"
data_path=f"traffic_BENCH_{BENCH}_CPE_{CPE}_EPR_{EPR}_ROUTING_{ROUTING}_V_{V}_D_{D}_TOPO_{TOPO}_SUFFIX_{SUFFIX}_.csv"
# traffic_BENCH_FFT3D nx=100 ny=100 nz=100 npRow=12_EPR_1_ROUTING_ASP_V_36_D_7_TOPO_RRG_SUFFIX_ROUTERLINKS16GBps_
_visual=traffic_visualizer(data_path, V, D, TOPO, EPR, SUFFIX)

# %%
_=_visual.get_accumulated_demand_matrix(True)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
(V, D) = (36, 7)
TOPO="RRG"
ROUTING="ASP"
EPR=2
CPE=2
BENCH="Alltoall bytes=100"
SUFFIX="ROUTERLINKS16GBps"
data_path=f"traffic_BENCH_{BENCH}_CPE_{CPE}_EPR_{EPR}_ROUTING_{ROUTING}_V_{V}_D_{D}_TOPO_{TOPO}_SUFFIX_{SUFFIX}_.csv"
# traffic_BENCH_FFT3D nx=100 ny=100 nz=100 npRow=12_EPR_1_ROUTING_ASP_V_36_D_7_TOPO_RRG_SUFFIX_ROUTERLINKS16GBps_
_visual=traffic_visualizer(data_path, V, D, TOPO, EPR, SUFFIX)

# %%
_=_visual.get_accumulated_demand_matrix(True) # TODO: get this from the statistic file
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
