# %%
from traffic_analyser import traffic_analyser
# Out:
# /users/ziyzhang/EFM_experiments/traffic_analyser/traffic_analyser.py:97: SyntaxWarning: assertion is always true, perhaps remove parentheses?
#   assert(0, "input arg '_method' is either 1 or 2")

# %% [markdown]
# /users/ziyzhang/EFM_experiments/Visualization/4_fullmesh/traffic_BENCH_Alltoall bytes=1000_EPR_1_ROUTING_ASP_V_4_D_3_TOPO_RRG_SUFFIX_ROUTER_LINKS_1GBps_1cpNic_.csv

# %%
Cap_core = 16
Cap_access = 16
V=36
D=5
EPR = (D+1)//2
topo_name="RRG"
data_path=f"/users/ziyzhang/EFM_experiments/EFM_experiments/traffic_traces/FFT3D nx=100 ny=100 nz=100 npRow=12.csv"

# %%
analyser=traffic_analyser(data_path, V, D, topo_name, EPR, Cap_core, Cap_access, "", processing_method=2)

# %%
analyser.sample_traffic(120, 1.0)
# Out:
# 119 incoming matrices, 88 left after filtering
# ([array([[ 0.        , 12.49158933,  0.        , ...,  0.        ,
#            0.        ,  0.        ],
#          [ 0.        ,  0.        , 11.58401253, ...,  0.        ,
#            0.        ,  0.        ],
#          [ 4.61765151,  0.        ,  0.        , ...,  0.        ,
#            0.        ,  0.        ],
#          ...,
#          [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#            8.40749371,  0.        ],
#          [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#            0.        ,  8.40749371],
#          [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#            0.        ,  0.        ]]),
#   array([[ 0.        ,  4.16386311,  4.16386311, ...,  0.        ,
#            0.        ,  0.        ],
#          [ 0.        ,  0.        ,  4.16386311, ...,  0.        ,
#            0.        ,  0.        ],
#          [ 9.23530302,  0.        ,  0.        , ...,  0.        ,
# ...
