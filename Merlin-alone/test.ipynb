# %%
import os
import glob
import sys
sys.path.append(os.path.abspath(os.getcwd()))
# sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..')))

from data_helper import get_data
import pandas as pd
import matplotlib.pyplot as plt

# %%
def get_data(abs_folder_path):
    _Time = 400000000
    # initialize a new pandas dataframe to store the results
    results_df = pd.DataFrame(columns=['load', 'ave_nlat', 'Phi', 'L_access'])
    for file_path in sorted(glob.glob(os.path.join(abs_folder_path, '*.csv'))):
        # the file name should be "load_{load}.csv", we will extract the load value from it
        load_value = float(os.path.basename(file_path).split('_')[1][:3])

        # read the csv file and store the data in a pandas dataframe
        df = pd.read_csv(file_path)

        filtered_df = df[(df[' StatisticName'] == ' network_latency') & (df[' SimTime']==_Time)]
        filtered_df = filtered_df.drop_duplicates(keep = 'first')
        AVE_LAT = filtered_df[' Sum.u64'].sum()/filtered_df[' Count.u64'].sum()

        filtered_df = df[(df['ComponentName'].str.contains('offered') ) & (df[' StatisticName'] == ' send_bit_count') & (df[' SimTime']==_Time)]
        filtered_df = filtered_df.drop_duplicates(keep = 'first')
        TOT_bit = filtered_df[' Sum.u64'].sum()
        TOT_BW = TOT_bit/8/(_Time/1000)

        EP_BW = TOT_BW/filtered_df[' Sum.u64'].size/1 # divided by the number of endpoints, and access link capcity 1GBps

        # append the data to the results_df
        results_df.loc[len(results_df.index)] = [load_value, AVE_LAT, TOT_BW, EP_BW]
    
    return results_df

# %%
folder_path = "/users/ziyzhang/EFM_experiments/Merlin-alone/uniform/RRG_36_7_ECMP_ASP"

# %%
file_path = folder_path+"/load_0.3.csv"
df = pd.read_csv(file_path)

_Time = 400000000
filtered_df = df[(df[' StatisticName'] == ' network_latency') & (df[' SimTime']==_Time)]
filtered_df = filtered_df.drop_duplicates(keep = 'first')
AVE_LAT = filtered_df[' Sum.u64'].sum()/filtered_df[' Count.u64'].sum()

filtered_df = df[(df['ComponentName'].str.contains('offered') ) & (df[' StatisticName'] == ' send_bit_count') & (df[' SimTime']==_Time)]
filtered_df = filtered_df.drop_duplicates(keep = 'first', subset=['ComponentName'])
TOT_bit = filtered_df[' Sum.u64'].sum()
TOT_BW = TOT_bit/8/(_Time/1000)

# %%
TOT_BW
# Out:
# 691.2

# %%
filtered_df[' Sum.u64'].size
# Out:
# 144

# %%
filtered_df
# Out:
#                   ComponentName    StatisticName  StatisticSubId  \
# 3100  offered_load_14:networkIF   send_bit_count
# 3105  offered_load_57:networkIF   send_bit_count
# 3110  offered_load_58:networkIF   send_bit_count
# 3115  offered_load_59:networkIF   send_bit_count
# 3186  offered_load_60:networkIF   send_bit_count
# ...                         ...              ...             ...
# 6028  offered_load_96:networkIF   send_bit_count
# 6035  offered_load_97:networkIF   send_bit_count
# 6040  offered_load_98:networkIF   send_bit_count
# 6098  offered_load_56:networkIF   send_bit_count
# 6122  offered_load_99:networkIF   send_bit_count
#
#       StatisticType    SimTime   Rank   Sum.u64     SumSQ.u64   Count.u64  \
# 3100    Accumulator  400000000      0  15360000  125829120000        1875
# 3105    Accumulator  400000000      0  15360000  125829120000        1875
# 3110    Accumulator  400000000      0  15360000  125829120000        1875
# 3115    Accumulator  400000000      0  15360000  125829120000        1875
# 3186    Accumulator  400000000      0  15360000  125829120000        1875
# ...             ...        ...    ...       ...           ...         ...
# 6028    Accumulator  400000000      0  15360000  125829120000        1875
# 6035    Accumulator  400000000      0  15360000  125829120000        1875
# 6040    Accumulator  400000000      0  15360000  125829120000        1875
# 6098    Accumulator  400000000      0  15360000  125829120000        1875
# 6122    Accumulator  400000000      0  15360000  125829120000        1875
#
#        Min.u64   Max.u64
# 3100      8192      8192
# 3105      8192      8192
# 3110      8192      8192
# 3115      8192      8192
# 3186      8192      8192
# ...        ...       ...
# 6028      8192      8192
# 6035      8192      8192
# 6040      8192      8192
# 6098      8192      8192
# 6122      8192      8192
#
# [144 rows x 11 columns]

# %%
file_path = folder_path+"/load_0.4.csv"
df = pd.read_csv(file_path)

_Time = 400000000
filtered_df = df[(df[' StatisticName'] == ' network_latency') & (df[' SimTime']==_Time)]
filtered_df = filtered_df.drop_duplicates(keep = 'first')
AVE_LAT = filtered_df[' Sum.u64'].sum()/filtered_df[' Count.u64'].sum()

filtered_df = df[(df['ComponentName'].str.contains('offered') ) & (df[' StatisticName'] == ' send_bit_count') & (df[' SimTime']==_Time)]
filtered_df = filtered_df.drop_duplicates(keep = 'first', subset=['ComponentName'])
TOT_bit = filtered_df[' Sum.u64'].sum()
TOT_BW = TOT_bit/8/(_Time/1000)

# %%
TOT_BW
# Out:
# 921.6

# %%
filtered_df[' Sum.u64'].size
# Out:
# 144

# %%
filtered_df
# Out:
#                   ComponentName    StatisticName  StatisticSubId  \
# 3097  offered_load_57:networkIF   send_bit_count
# 3103  offered_load_86:networkIF   send_bit_count
# 3108  offered_load_87:networkIF   send_bit_count
# 3121  offered_load_14:networkIF   send_bit_count
# 3126  offered_load_15:networkIF   send_bit_count
# ...                         ...              ...             ...
# 6082  offered_load_85:networkIF   send_bit_count
# 6107  offered_load_24:networkIF   send_bit_count
# 6112  offered_load_25:networkIF   send_bit_count
# 6117  offered_load_26:networkIF   send_bit_count
# 6122  offered_load_27:networkIF   send_bit_count
#
#       StatisticType    SimTime   Rank   Sum.u64     SumSQ.u64   Count.u64  \
# 3097    Accumulator  400000000      0  20480000  167772160000        2500
# 3103    Accumulator  400000000      0  20480000  167772160000        2500
# 3108    Accumulator  400000000      0  20480000  167772160000        2500
# 3121    Accumulator  400000000      0  20480000  167772160000        2500
# 3126    Accumulator  400000000      0  20480000  167772160000        2500
# ...             ...        ...    ...       ...           ...         ...
# 6082    Accumulator  400000000      0  20480000  167772160000        2500
# 6107    Accumulator  400000000      0  20480000  167772160000        2500
# 6112    Accumulator  400000000      0  20480000  167772160000        2500
# 6117    Accumulator  400000000      0  20480000  167772160000        2500
# 6122    Accumulator  400000000      0  20480000  167772160000        2500
#
#        Min.u64   Max.u64
# 3097      8192      8192
# 3103      8192      8192
# 3108      8192      8192
# 3121      8192      8192
# 3126      8192      8192
# ...        ...       ...
# 6082      8192      8192
# 6107      8192      8192
# 6112      8192      8192
# 6117      8192      8192
# 6122      8192      8192
#
# [144 rows x 11 columns]
